# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 27.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 1.9 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 11.3 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
# ...

# %%
import yaml

data_yaml = dict(
    train = '/kaggle/input/licencedata/licenceData/train/images',  # path to training images
    val = '/kaggle/input/licencedata/licenceData/valid/images',      # path to validation images
    nc = 1,                                             # number of classes
    names = ['chart']               # class names
)

# Save YAML
with open('your_dataset.yaml', 'w') as outfile:
    yaml.dump(data_yaml, outfile, default_flow_style=False)

# %%
import time
from ultralytics import YOLO

# Load the pre-trained YOLOv5s model
model = YOLO('yolov5s.pt')  # You can use 'yolov5m.pt', 'yolov5l.pt', etc.
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 17.7M/17.7M [00:00<00:00, 151MB/s]

# %%
# !yolo task=detect mode=train model=/kaggle/working/yolov5su.pt data=/kaggle/working/your_dataset.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.119 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r best_model.zip /kaggle/working/runs/detect/train/weights/best.pt
# Out:
#   adding: kaggle/working/runs/detect/train/weights/best.pt (deflated 8%)

# %%
from IPython.display import FileLink

# Zip it first
# !zip -r last_model.zip /kaggle/working/runs/detect/train/weights/last.pt

# Create a download link
FileLink('last_model.zip')
# Out:
#   adding: kaggle/working/runs/detect/train/weights/last.pt (deflated 8%)
# /kaggle/working/last_model.zip
